# %%
class Human:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  # メソッドを定義
  def printinfo(self):
    print(f"名前は{self.name}、年齢は{self.age}")

man = Human('鎌田',50)

man.printinfo()
# Out:
# 名前は鎌田、年齢は50
