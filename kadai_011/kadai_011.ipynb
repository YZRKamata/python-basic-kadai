# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for star in array:
  print(star)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
i = 0

while i <= 8:
  print(array[i])
  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
